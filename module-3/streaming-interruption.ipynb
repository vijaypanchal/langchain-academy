# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_groq langgraph_sdk

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://docs.langchain.com/oss/python/langgraph/streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("GROQ_API_KEY")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display
from typing import Literal

from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatGroq(model="openai/gpt-oss-120b", temperature=0) 

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State)-> Literal ["summarize_conversation",END]:
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state) for graph state.
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content='Hey Lance! 👋 Great to meet you. How can I help you today?', additional_kwargs={'reasoning_content': 'The user says "hi! I\'m Lance". We need to respond appropriately. It\'s a greeting. We can respond friendly, ask how can help. No policy issues.'}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 75, 'total_tokens': 135, 'completion_time': 0.123923596, 'completion_tokens_details': {'reasoning_tokens': 34}, 'prompt_time': 0.002854242, 'prompt_tokens_details': None, 'queue_time': 0.286511655, 'total_time': 0.126777838}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_93703442d9', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f55fd-e8d1-70c2-b96b-65d1b04f8a2f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 75, 'output_tokens': 60, 'total_tokens': 135, 'output_token_details': {'reasoning': 34}})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hey again, Lance! 👋 What’s on your mind today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hey Lance! 👋 Great to meet you. How can I help you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://docs.langchain.com/oss/python/langchain/models#advanced-streaming-topics:streaming-events), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# ...
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_stream. Name: ChatGroq
# Node: conversation. Type: on_chat_model_end. Name: ChatGroq
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'The'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' user'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' asks'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ':'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' "'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'Tell'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' me'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' about'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' the'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' '}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '49'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'ers'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' NFL'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' team'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '".'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' This'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' is'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' a'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' straightforward'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' request'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' for'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' information'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' about'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' the'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' San'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' Francisco'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' '}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '49'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'ers'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' No'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' dis'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': 'allowed'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' content'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' Provide'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' a'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' comprehensive'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' overview'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ':'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' history'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' championships'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' notable'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' players'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' recent'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' performance'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' stadium'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ','}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' etc'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' Should'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' be'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': ' safe'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={'reasoning_content': '.'}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='San', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Franc', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='isco', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Overview', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Category', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Details', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='----------', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='---------', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Founded', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='6', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='original', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ly', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' part', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' All', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='‑', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='America', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' joined', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='195', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Location', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Franc', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='isco', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bay', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Area', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Home', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Le', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='vi', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='opened', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' capacity', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ~', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='68', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='500', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Team', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Colors', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Scarlet', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' red', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' gold', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' “', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='”', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' white', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Masc', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ot', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' S', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ourd', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ough', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Sam', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Owner', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' /', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Management', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Owner', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Den', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ise', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' De', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Bart', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='olo', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' York', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='York', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' family', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' –', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' President', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='John', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' York', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=';', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' General', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Manager', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# ...
# {'chunk': AIMessageChunk(content='single', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' season', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='797', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Roger', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Craig', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Most', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Receiving', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Y', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ards', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='single', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' season', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='848', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Jerry', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Rice', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |\n', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Most', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' S', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='acks', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='career', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='84', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Frank', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\u202f', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='G', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='iff', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ord', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='actually', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' not', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={'model_provider': 'groq'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'length', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_dd854ee2d7', 'service_tier': 'on_demand'}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 80, 'output_tokens': 3072, 'total_tokens': 3152, 'output_token_details': {'reasoning': 59}}, tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--019f55ff-ec5a-7c02-adc3-c69e9ae80d4f', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||##| San| |Franc|isco| |49|ers| –| A| Complete| Snapshot| (|202|4|)
#
# ||| Item| || Details| |
# |||------|||---------||
# ||| **|Founded|**| || |194|6| (|AA|FC|);| joined| the| NFL| in| |195|0| |
# ||| **|Location|**| || San| |Franc|isco| Bay| Area|,| California| |
# ||| **|Home| Stadium|**| || **|Le|vi|’s| Stadium|**| –| Santa| Clara|,| CA| (|capacity| ~|68|,|500|)| |
# ||| **|Team| Colors|**| || Scarlet| red|,| gold|,| white| |
# ||| **|Owner|**| || De| |Bart|olo| family| (|John| |York| is| the| principal| owner|)| |
# ||| **|President| /| CEO|**| || **|Al| |Le|vy|**| |
# ||| **|General| Manager|**| || **|John| |L|ynch|**| (|since| |201|7|)| |
# ||| **|Head| Coach|**| || **|Kyle| |Sh|an|ahan|**| (|since| |201|7|)| |
# ||| **|Conference| /| Division|**| || NFC| |West| |
# ||| **|R|ival|ries|**| || Seattle| Seahawks|,| Los| |Ang|eles| Rams|,| Arizona| Cardinals| (|division|);| historic| rivalry| with| Dallas| Cowboys| |
# ||| **|Masc|ot|**| || **|S|ourd|ough| Sam|**| |
# ||| **|Official| Website|**| || [|49|ers|.com|](|https|://|www|.|49|ers|.com|)| |
#
# |---
#
# |###| |1|.| Historical| Highlights|
#
# ||| Era| || Key| Points| |
# |||-----|||------------||
# ||| **|Early| Years| (|194|6|‑|197|8|)**| || •| Joined| NFL| in| |195|0|.| <|br|>|•| First| playoff| appearance| in| |197|0| under| coach| Dick| |N|olan|.| |
# ||| **|Bill| Walsh| &| the| West| Coast| Off|ense| (|197|9|‑|198|8|)**| || •| Walsh| introduced| the| “|West| Coast| Off|ense|.”| <|br|>|•| Draft|ed| quarterback| **|Joe| |Mont|ana|**| (|197|9|).| |
# ||| **|Dyn|asty| (|198|1|‑|199|4|)**| || •| **|5| Super| Bowl| titles|**| (|X|VI| |198|2|,| XIX| |198|5|,| XX|III| |198|9|,| XX|IV| |199|0|,| XX|IX| |199|5|).| <|br|>|•| Hall|‑|of|‑|F|ame| stars|:| Montana|,| Jerry| |Rice|,| Ronnie| |L|ott|,| Steve| |Young|,| Roger| |Craig|,| Charles| |Hal|ey|,| etc|.| |
# ||| **|Post|‑|Dyn|asty| &| Re|building| (|199|5|‑|200|9|)**| || •| Won| Super| Bowl| |XX|IX| (|199|5|)| with| Steve| |Young|.| <|br|>|•| Period| of| incons|istency|;| notable| moments| include| the| “|T|uck| Rule|”| game| (|200|1|)| and| the| “|M|ortal| Komb|at|”| comeback| vs|.| the| Giants| (|200|2|).| |
# ||| **|Jim| Har|b|augh| Era| (|201|1|‑|201|4|)**| || •| Turn|ed| the| franchise| around|;| reached| Super| Bowl| |XL|VII| (|201|2|)| but| lost| to| the| Ravens|.| |
# ||| **|Kyle| Shan|ahan| Era| (|201|7|‑|present|)**| || •| Re|built| with| a| creative| offense| and| stout| defense|.| <|br|>|•| Re|ached| Super| Bowl| |L|IV| (|202|0|)| –| lost| to| the| Chiefs|.| <|br|>|•| Cons|ist|ently| in| the| playoffs| (|201|9|‑|202|3|).| |
#
# |---
#
# |###| |2|.| Championships| &| Play|off| Success|
#
# ||| Competition| || Titles| || Years| |
# |||-------------|||--------|||-------||
# ||| **|Super| Bowl|**| || |5| || |198|2| (|X|VI|),| |198|5| (|X|IX|),| |198|9| (|XX|III|),| |199|0| (|XX|IV|),| |199|5| (|XX|IX|)| |
# ||| **|NFL| Championship| (|pre|‑|Super| Bowl|)**| || |2| || |195|1|,| |195|5| |
# ||| **|N|FC| Championship|**| || |7| || |198|1|,| |198|4|,| |198|8|,| |198|9|,| |199|4|,| |201|2|,| |201|9| |
# ||| **|Division| Titles| (|N|FC| West|)**| || |22| (|as| of| |202|3|)| || |197|0|‑|197|2|,| |197|7|‑|197|8|,| |198|1|‑|199|8| (|multiple|),| |200|2|,| |201|1|‑|201|2|,| |201|9|‑|202|3| |
#
# |---
#
# |###| |3|.| Icon|ic| Players| (|Hall| of| Fame|)
#
# ||| Position| || Player| || Years| with| |49|ers| || Hall| of| Fame| Ind|uction| |
# |||----------|||--------|||----------------|--|||----------------|--------||
# ||| QB| || **|Joe| |Mont|ana|**| || |197|9|‑|199|2| || |200|0| |
# ||| QB| || **|Steve| |Young|**| || |199|1|‑|200|0| || |200|5| |
# ||| RB| || **|Roger| |Craig|**| || |198|3|‑|199|0| || |201|4| |
# ||| WR| || **|Jerry| |Rice|**| || |198|5|‑|200|0| || |201|0| |
# ||| DB| || **|Ron|nie| |L|ott|**| || |198|1|‑|199|0| || |200|0| |
# ||| DE| || **|Charles| |Hal|ey|**| || |198|3|‑|199|1| || |201|5| |
# ||| TE| || **|Dw|ight| |Clark|**| || |197|9|‑|198|7| || |201|8| |
# ||| LB| || **|Patrick| |Phill|ips|**| || |197|0|‑|197|9| || |202|1| |
# ||| K| || **|Ray| |W|es|ley|**| || |197|7|‑|199|4| || |201|6| |
#
# |**|Modern| stand|‑|outs| (|not| yet| Hall| of| Fam|ers|)**|
# |-| **|George| |K|ittle|**| (|TE|)| –| multiple| All|‑|Pro| selections|,| franchise| receiving|‑|yard|age| record| holder|.|
# |-| **|Nick| |B|osa|**| (|DE|)| –| |202|0| Defensive| Rookie| of| the| Year|,| |202|2| NFL| Defensive| Player| of| the| Year|.|
# |-| **|De|ebo| |Samuel|**| (|WR|/R|B|)| –| versatile| “|wide|‑|back|”| weapon|.|
# |-| **|Christian| |Mc|C|aff|rey|**| (|RB|)| –| elite| dual|‑|th|reat| when| healthy|.|
# |-| **|Fred| |War|ner|**| (|LB|)| –| leader| of| a| top|‑|10| defense|.
#
# |---
#
# |###| |4|.| Recent| Seasons| (|202|0|‑|202|3|)
#
# ||| Season| || Record| (|Reg|.)| || Play|off| Result| || Not|able| Story|lines| |
# |||--------|||---------------|||----------------|||----------------|----||
# ||| **|202|0|**| || |11|‑|5| || Lost| Super| Bowl| |L|IV| to| KC| Chiefs| (|31|‑|20|)| || Kyle| |Sh|an|ahan|’s| offense| peaked|;| Jimmy| |Gar|opp|olo| at| QB|;| Nick| |B|osa| (|R|ookie|)| Defensive| RO|Y| |
# ||| **|202|1|**| || |10|‑|7| || Lost| NFC| Wild|‑|Card| to| Green| Bay| (|13|‑|10|)| || Inj|uries| to| Gar|opp|olo| &| Mc|C|aff|rey| limited| offense| |
# ||| **|202|2|**| || |13|‑|4| || Lost| NFC| Div|isional| to| Dallas| (|19|‑|12|)| || Strong| defensive| line| (|B|osa|,| Ar|ik| |Arm|stead|);| K|ittle| set| franchise| receiving|‑|yards| record| |
# ||| **|202|3|**| || |12|‑|5| || Lost| NFC| Championship| to| Philadelphia| (|31|‑|7|)| || Brock| |P|ond|ex|ter| took| over| at| QB| after| Gar|opp|olo|’s| injury|;| defense| forced| |5| turnovers| in| the| championship| game| |
#
# |**|Trend|:**| The| |49|ers| have| been| among| the| league|’s| top| defenses| (|top|‑|5| in| points| allowed| in| |202|2| &| |202|3|)| while| Shan|ahan|’s| offense| remains| one| of| the| most| creative|,| relying| heavily| on| play|‑|action|,| tight|‑|end| usage|,| and| versatile| backs|.
#
# |---
#
# |###| |5|.| Coaching| &| Front|‑|Office| Philosophy|
#
# ||| Role| || Person| (|202|4|)| || Core| Philosophy| |
# |||------|||---------------|||----------------|-||
# ||| **|Head| Coach|**| || **|Kyle| |Sh|an|ahan|**| || Creative|,| motion|‑|heavy| play|‑|calling|;| balanced| run|‑|pass| attack|;| maxim|izes| talent| in| the| West|‑|Co|ast| scheme|.| |
# ||| **|Off|ensive| Coordinator|**| || **|Mike| |Mc|Daniel|**| || Ext|ends| Shan|ahan|’s| concepts| with| more| spread| and| R|PO| elements|.| |
# ||| **|Def|ensive| Coordinator|**| || **|De|M|eco| |R|yans|**| (|depart|ed| |202|3|)| –| **|new| DC| TBD| (|202|4|)**| || Historically| aggressive| |4|‑|3| base| with| hybrid| sub|‑|packages|;| emphasis| on| pass| rush| and| turnover| creation|.| |
# ||| **|General| Manager|**| || **|John| |L|ynch|**| || Draft|‑|first|,| character|‑|focused| roster| building|;| maintains| salary|‑|cap| flexibility|.| |
# ||| **|Owner|**| || **|John| |York| /| De| |Bart|olo| family|**| || Long|‑|term| stability|,| fan| experience|,| community| outreach|.| |
#
# |---
#
# |###| |6|.| Fan| Culture| &| Trad|itions|
#
# ||| Tradition| || Description| |
# |||-----------|||-------------||
# ||| **|“|The| Faith|ful|”|**| || Nick|name| for| the| |49|ers| fan| base|;| known| for| loyalty| through| highs| and| lows|.| |
# ||| **|Red|‑|and|‑|Gold| Att|ire|**| || Scarlet| shirts|,| gold| hats|,| and| “|49|ers|”| scarves| dominate| Levi|’s| Stadium| on| game| day|.| |
# ||| **|“|The| |49|ers| March|”|**| || Fans| line| the| stadium| steps| before| kickoff|,| chanting| “|We|’re| the| |49|ers|!”| |
# ||| **|“|The| |49|ers| Hall| of| Fame|”|**| || Museum| at| the| team|’s| Santa| Clara| headquarters|;| free| tours| for| fans|.| |
# ||| **|Community| Work|**| || The| |49|ers| Foundation| supports| youth| education|,| health|,| and| disaster| relief| throughout| the| Bay| Area|.| |
#
# |---
#
# |###| |7|.| Not|able| Records| &| Trivia|
#
# ||| Record| || Detail| |
# |||--------|||--------||
# ||| **|Most| Super| Bowl| Wins| (|N|FC|)**| || |5| (|t|ied| with| Dallas| Cowboys|)| |
# ||| **|Longest| Regular|‑|Season| Winning| St|reak|**| || |18| games| (|198|8|‑|199|0|)| |
# ||| **|Most| Points| in| a| Super| Bowl|**| || |55| (|Super| Bowl| |XX|IV|,| |199|0|)| |
# ||| **|First| Team| to| Popular|ize| the| “|West| Coast| Off|ense|”|**| || Implement|ed| by| Bill| Walsh| in| early| |198|0|s| |
# ||| **|Only| Team| to| Win| a| Super| Bowl| After| Starting| |0|‑|2|**| || |199|4| (|won| Super| Bowl| |XX|IX|)| |
# ||| **|First| NFL| Team| to| Have| a| Player| Win| the| He|isman| and| a| Super| Bowl|**| || Not| a| single| player|,| but| the| franchise| has| produced| multiple| He|isman| winners| (|e|.g|.,| Aaron| |Rod|gers|’| college| teammate|,| not| a| |49|er|)| –| a| fun| foot|note|.| |
#
# |---
#
# |###| |8|.| How| to| Follow| the| |49|ers|
#
# ||| Platform| || How| to| Access| |
# |||----------|||---------------||
# ||| **|Official| Site|**| || [|www|.|49|ers|.com|](|https|://|www|.|49|ers|.com|)| –| news|,| tickets|,| merch| |
# ||| **|Social| Media|**| || Twitter|:| **|@|49|ers|**|;| Instagram|:| **|@|49|ers|**|;| Tik|Tok|:| **|@|49|ers|**| |
# ||| **|TV| Broadcast|**| || Local|:| NBC| Bay| Area| (|non|‑|national| games|).| National|:| CBS|,| FOX|,| NBC|,| ESPN|,| Amazon| Prime| (|stream|ing|).| |
# ||| **|Radio|**| || |95|.|7| |FM| (|K|GM|Z|)| –| English| play|‑|by|‑|play|;| |96|.|1| |FM| (|K|KS|F|)| –| Spanish| broadcast| |
# ||| **|Mobile| App|**| || “|49|ers| Official| App|”| –| live| scores|,| highlights|,| exclusive| behind|‑|the|‑|sc|enes| content| |
# ||| **|Ticket| Purchase|**| || Official| site|,| Ticket|master|,| NFL| Ticket| Exchange|;| sign| up| for| the| team|’s| mailing| list| for| pre|‑|sale| alerts|.| |
#
# |---
#
# |###| |9|.| Quick| FAQ|
#
# |**|Q|:| Who| is| the| current| starting| quarterback|?|**|
# |**|A|:**| As| of| the| |202|4| season|,| **|B|rock| |P|ond|ex|ter|**| is| the| starter| after| Jimmy| |Gar|opp|olo|’s| departure|.| (|Check| the| latest| roster| for| any| updates|.)
#
# |**|Q|:| When| is| the| next| big| rivalry| game|?|**|
# |**|A|:**| The| NFC| |West| schedule| rotates|;| the| |49|ers| usually| open| the| season| with| a| division| opponent|—|often| the| **|Seattle| Seahawks|**| or| **|Los| |Ang|eles| Rams|**|.
#
# |**|Q|:| How| can| I| buy| tickets|?|**|
# |**|A|:**| Purchase| through| the| official| |49|ers| website|,| Ticket|master|,| or| the| NFL| Ticket| Exchange|.| Joining| the| team|’s| email| list| gives| you| early|‑|access| codes|.
#
# |**|Q|:| What|’s| the| mascot|’s| name|?|**|
# |**|A|:**| **|S|ourd|ough| Sam|**,| a| gold|‑|min|ing| pros|pector| who| appears| at| home| games| and| community| events|.
#
# |---
#
# |##| Bottom| Line|
#
# |The| San| |Franc|isco| |49|ers| are| one| of| the| NFL|’s| most| stor|ied| franchises|—|five| Super| Bowl| championships|,| a| legacy| of| innovative| offense|,| and| a| passionate| fan| base| that| spans| generations|.| Under| Kyle| |Sh|an|ahan|’s| inventive| coaching| and| a| front| office| focused| on| talent| and| culture|,| the| team| remains| a| perennial| contender|,| aiming| to| add| a| sixth| Lomb|ardi| Trophy| to| its| illustri|ous| history|.| Whether| you|’re| a| longtime| “|Faith|ful|”| or| a| newcomer| to| the| sport|,| the| |49|ers| offer| a| rich| past|,| an| exciting| present|,| and| a| promising| future|.| **|Go| N|iners|!|**|||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# The LangGraph API  [supports editing graph state](https://docs.langchain.com/langsmith/add-human-in-the-loop).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %% [markdown]
# Let's [stream `values`](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '019f5605-996e-7ad0-b3b2-e7e0df2420b0', 'attempt': 1}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'e67c7282-1af8-4d09-8bda-f782c2c09f74'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'e67c7282-1af8-4d09-8bda-f782c2c09f74'}, {'content': '', 'additional_kwargs': {'reasoning_content': 'The user wants to multiply 2 and 3. Use multiply function.', 'tool_calls': [{'id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'token_usage': {'completion_tokens': 49, 'prompt_tokens': 212, 'total_tokens': 261, 'completion_time': 0.104369752, 'completion_tokens_details': {'reasoning_tokens': 16}, 'prompt_time': 0.008953357, 'prompt_tokens_details': None, 'queue_time': 0.282628729, 'total_time': 0.113323109}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_e1a78f200e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019f5605-9b93-7273-927c-7982e39da03e-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 212, 'output_tokens': 49, 'total_tokens': 261, 'output_token_details': {'reasoning': 16}}}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'e67c7282-1af8-4d09-8bda-f782c2c09f74'}, {'content': '', 'additional_kwargs': {'reasoning_content': 'The user wants to multiply 2 and 3. Use multiply function.', 'tool_calls': [{'id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'token_usage': {'completion_tokens': 49, 'prompt_tokens': 212, 'total_tokens': 261, 'completion_time': 0.104369752, 'completion_tokens_details': {'reasoning_tokens': 16}, 'prompt_time': 0.008953357, 'prompt_tokens_details': None, 'queue_time': 0.282628729, 'total_time': 0.113323109}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_e1a78f200e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019f5605-9b93-7273-927c-7982e39da03e-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 212, 'output_tokens': 49, 'total_tokens': 261, 'output_token_details': {'reasoning': 16}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'ff9a270d-8444-43ac-aa43-8e03c99ddcce', 'tool_call_id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'artifact': None, 'status': 'success'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'e67c7282-1af8-4d09-8bda-f782c2c09f74'}, {'content': '', 'additional_kwargs': {'reasoning_content': 'The user wants to multiply 2 and 3. Use multiply function.', 'tool_calls': [{'id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'token_usage': {'completion_tokens': 49, 'prompt_tokens': 212, 'total_tokens': 261, 'completion_time': 0.104369752, 'completion_tokens_details': {'reasoning_tokens': 16}, 'prompt_time': 0.008953357, 'prompt_tokens_details': None, 'queue_time': 0.282628729, 'total_time': 0.113323109}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_e1a78f200e', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019f5605-9b93-7273-927c-7982e39da03e-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 212, 'output_tokens': 49, 'total_tokens': 261, 'output_token_details': {'reasoning': 16}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'ff9a270d-8444-43ac-aa43-8e03c99ddcce', 'tool_call_id': 'fc_2741d931-2df6-4c85-93fa-1612faf9e260', 'artifact': None, 'status': 'success'}, {'content': 'The product of 2 and 3 is **6**.', 'additional_kwargs': {'reasoning_content': 'The user wants to multiply 2 and 3. The function returned 6. Need to respond with answer.'}, 'response_metadata': {'token_usage': {'completion_tokens': 46, 'prompt_tokens': 243, 'total_tokens': 289, 'completion_time': 0.09511862, 'completion_tokens_details': {'reasoning_tokens': 24}, 'prompt_time': 0.01098357, 'prompt_tokens_details': None, 'queue_time': 0.282073417, 'total_time': 0.10610219}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_93703442d9', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019f5605-9dd8-7010-bc13-f37404634e91-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 243, 'output_tokens': 46, 'total_tokens': 289, 'output_token_details': {'reasoning': 24}}}]}, id=None)

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={} response_metadata={} id='a257655a-f2ed-4087-924f-70f13702c735'
# =========================
# content='' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 212, 'output_tokens': 61, 'total_tokens': 273, 'output_token_details': {'reasoning': 28}}, 'reasoning_content': 'The user asks "Multiply 2 and 3". We need to use the multiply function. Provide the result. Use function call.', 'tool_calls': [{'id': 'fc_196cd638-b624-40a6-bfb6-7d5e0fb2f7e8', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 212, 'total_tokens': 273, 'completion_time': 0.12798162, 'completion_tokens_details': {'reasoning_tokens': 28}, 'prompt_time': 0.009107147, 'prompt_tokens_details': None, 'queue_time': 0.282428679, 'total_time': 0.137088767}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_c868cf1eaa', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f5605-a595-7243-bc8b-b5dd93afb1d6-0' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'fc_196cd638-b624-40a6-bfb6-7d5e0fb2f7e8', 'type': 'tool_call'}] invalid_tool_calls=[]
# =========================
# content='6' name='multiply' id='c12e73dd-6749-4cea-a11e-65993dd34e4d' tool_call_id='fc_196cd638-b624-40a6-bfb6-7d5e0fb2f7e8'
# =========================
# content='The product of 2 and 3 is **6**.' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 243, 'output_tokens': 46, 'total_tokens': 289, 'output_token_details': {'reasoning': 24}}, 'reasoning_content': 'The user wants "Multiply 2 and 3". The function returned 6. Need to respond with result.'} response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 243, 'total_tokens': 289, 'completion_time': 0.095674178, 'completion_tokens_details': {'reasoning_tokens': 24}, 'prompt_time': 0.009814349, 'prompt_tokens_details': None, 'queue_time': 0.283466606, 'total_time': 0.105488527}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_df9620fe21', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f5605-a7a0-7e01-9351-65e55b3da61d-0' tool_calls=[] invalid_tool_calls=[]
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can  [use `messages` mode](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# <!--You can dig further into the types [~here~](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages) [here](https://docs.langchain.com/oss/python/langgraph/concepts/langgraph_server). -->
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata and response_metadata.get("finish_reason"):
                    print(f"Response Metadata: Finish Reason - {response_metadata['finish_reason']}")                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 019f5607-9b0f-7923-ae13-14156e785561
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: fc_a52e7da3-0a57-41f6-b3f7-eca4ae9d8086, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: fc_a52e7da3-0a57-41f6-b3f7-eca4ae9d8086, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: fc_a52e7da3-0a57-41f6-b3f7-eca4ae9d8086, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# AI: The
# --------------------------------------------------
# AI: The product
# --------------------------------------------------
# AI: The product of
# --------------------------------------------------
# AI: The product of
# --------------------------------------------------
# AI: The product of 2
# --------------------------------------------------
# AI: The product of 2 and
# --------------------------------------------------
# AI: The product of 2 and
# --------------------------------------------------
# AI: The product of 2 and 3
# --------------------------------------------------
# AI: The product of 2 and 3 is
# --------------------------------------------------
# AI: The product of 2 and 3 is **
# --------------------------------------------------
# AI: The product of 2 and 3 is **6
# --------------------------------------------------
# AI: The product of 2 and 3 is **6**
# --------------------------------------------------
# AI: The product of 2 and 3 is **6**.
# --------------------------------------------------
# AI: The product of 2 and 3 is **6**.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: The product of 2 and 3 is **6**.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
